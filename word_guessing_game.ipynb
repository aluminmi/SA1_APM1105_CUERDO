# %%
#Question 1
import requests
url = 'https://raw.githubusercontent.com/AllenDowney/ThinkPython2/master/code/words.txt'
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
# Save the content of the response to a file
    with open('words.txt', 'wb') as f:
        f.write(response.content)
        print('Dataset saved to file.')
else:
    print('Failed to download dataset.')
# Out:
# Dataset saved to file.

# %%
import random
# Function to read the words from the file and return a random word
def get_word():
    with open('words.txt', 'r') as f:
        words = f.readlines()
    return random.choice(words).strip()

# Function to display the current state of the word
def display_word(word, guessed_letters):
    displayed_word = ''
    for letter in word:
        if letter in guessed_letters:
            displayed_word += letter + ' '
        else:
            displayed_word += '_ '
    return displayed_word.strip()

# Function to get the player's guess
def get_guess():
    while True:
        guess = input('Guess a letter: ').lower()
        if len(guess) == 1 and guess.isalpha():
            return guess
        else:
            print('Invalid input. Please enter a single letter.')

# Main function to run the game
def main():
    print('Welcome to the word guessing game!')
    word = get_word()
    max_guesses = 8
    guessed_letters = set()
    while max_guesses > 0:
        print(f'Word: {display_word(word, guessed_letters)}')
        print(f'Guesses left: {max_guesses}')
        guess = get_guess()
        if guess in guessed_letters:
            print('You already guessed that letter. Please try again.')
        else:
            guessed_letters.add(guess)
            if guess in word:
                if set(word) == guessed_letters:
                    print(f'Congratulations, you guessed the word {word}!')
                else:
                    print(f'Correct! The letter "{guess}" is in the word.')
            else:
                max_guesses -= 1
                print(f'Sorry, the letter "{guess}" is not in the word.')
                if max_guesses == 0:
                    print(f'Sorry, you ran out of guesses. The word was {word}.')
        if set(word) == guessed_letters:
            word = get_word()
            max_guesses = 8
            guessed_letters = set()
    print('Thanks for playing!')
if __name__ == '__main__':
    main()
# Out:
# Welcome to the word guessing game!
# Word: _ _ _ _ _ _ _ _ _ _
# Guesses left: 8
# Guess a letter: N
# Sorry, the letter "n" is not in the word.
# Word: _ _ _ _ _ _ _ _ _ _
# Guesses left: 7
# Guess a letter: d
# Sorry, the letter "d" is not in the word.
# Word: _ _ _ _ _ _ _ _ _ _
# Guesses left: 6
# Guess a letter: f
# Sorry, the letter "f" is not in the word.
# Word: _ _ _ _ _ _ _ _ _ _
# Guesses left: 5
# Guess a letter: v
# Sorry, the letter "v" is not in the word.
# Word: _ _ _ _ _ _ _ _ _ _
# Guesses left: 4
# Guess a letter: e
# Correct! The letter "e" is in the word.
# Word: _ _ _ _ _ _ _ _ e _
# Guesses left: 4
# Guess a letter: 3
# Invalid input. Please enter a single letter.
# Guess a letter: a
# Correct! The letter "a" is in the word.
# Word: _ _ a _ _ _ _ _ e _
# Guesses left: 4
# Guess a letter: s
# Correct! The letter "s" is in the word.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 4
# Guess a letter: l
# Sorry, the letter "l" is not in the word.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 3
# Guess a letter: d
# You already guessed that letter. Please try again.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 3
# Guess a letter: v
# You already guessed that letter. Please try again.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 3
# Guess a letter: e
# You already guessed that letter. Please try again.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 3
# Guess a letter: r
# Sorry, the letter "r" is not in the word.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 2
# Guess a letter: l
# You already guessed that letter. Please try again.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 2
# Guess a letter: m
# Sorry, the letter "m" is not in the word.
# Word: _ _ a s _ _ _ _ e s
# Guesses left: 1
# Guess a letter: c
# Correct! The letter "c" is in the word.
# Word: c _ a s _ _ _ _ e s
# Guesses left: 1
# Guess a letter: s
# You already guessed that letter. Please try again.
# Word: c _ a s _ _ _ _ e s
# Guesses left: 1
# Guess a letter: e
# You already guessed that letter. Please try again.
# Word: c _ a s _ _ _ _ e s
# Guesses left: 1
# Guess a letter: b
# Sorry, the letter "b" is not in the word.
# Sorry, you ran out of guesses. The word was chastities.
# Thanks for playing!
